# %% [markdown]
# # <u> Architectural Plan GAN Generator </u>

# %% [markdown]
# # Setup

# %%
import tensorflow as tf
import keras

import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time

from IPython import display

# %%
np.version.version
# Out:
# '1.21.1'

# %% [markdown]
# ## Load Dataset
#
# #### 500 x 500 dataset

# %%
folder_path = r"C:\Users\johnd\Desktop\Dataset\Archidata\1600 Dataset\Expanded Dataset 500 x 500"
images = []
for filename in os.listdir(folder_path):
    full_filename = os.path.join(folder_path, filename)
    with PIL.Image.open(full_filename) as image:
        new_image = image.convert(mode='L')
        images.append(np.asarray(new_image))
        
#images = np.asarray(images)

# %%
np.asarray(images).shape
# Out:
# (1600, 500, 500)

# %%
images[1].shape
# Out:
# (500, 500)

# %%
plt.imshow((images[170]),cmap="gray")

# %%
train_images = np.stack(images, axis = 0)
train_images = train_images.reshape(train_images.shape[0],500,500,1)

# %%
train_images = (train_images - 127.5) / 127.5  # Normalize the images to [-1, 1]

# %%
train_images.shape
# Out:
# (1600, 500, 500, 1)

# %% [markdown]
# ## Buffer and Batch size

# %%
# Split dataset and Shuffle
BUFFER_SIZE = train_images.shape[0]
BATCH_SIZE = 50
train_dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# # Models

# %% [markdown]
# ## Generator Model

# %%
def make_generator_model():
    model = tf.keras.Sequential()
    model.add(layers.Dense(25*25*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((25, 25, 256)))
    assert model.output_shape == (None, 25, 25, 256)  # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (20, 20), strides=(5, 5), padding='same', use_bias=False))
    assert model.output_shape == (None, 125, 125, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (20, 20), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 250, 250, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(1, (20, 20), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, 500, 500, 1)

    return model

# %%
generator = make_generator_model()

# %%
noise = tf.random.normal([1, 100])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0], cmap='gray')

# %% [markdown]
# ## Discriminator Model

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (20, 20), strides=(5, 5), padding='same',
                                     input_shape=[500, 500, 1]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (20, 20), strides=(5, 5), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1))

    return model

# %%
discriminator = make_discriminator_model()

# %%
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[-4.775611e-07]], shape=(1, 1), dtype=float32)

# %% [markdown]
# ## Define the loss and optimizers

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %% [markdown]
# ## Discriminator loss

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %% [markdown]
# ## Generator loss

# %%
def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %% [markdown]
# ## Optimizers

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %% [markdown]
# ## Save checkpoints

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %% [markdown]
# # Define the training loop

# %%
EPOCHS = 100
noise_dim = 100
num_examples_to_generate = 9

# You will reuse this seed overtime (so it's easier)
# to visualize progress in the animated GIF)
seed = tf.random.normal([num_examples_to_generate, noise_dim])

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(noise, training=True)

        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

        gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
        gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

        generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
        discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))
        
#         print("generator loss: ",np.mean(gen_loss))
#         print("discriminator loss: ",np.mean(disc_loss))

#         print("generator loss: ",tf.Tensor.eval(np.mean(gen_loss)).numpy())
#         print("discriminator loss: ",tf.Tensor.eval(np.mean(disc_loss)).numpy())

# %%
def train(dataset, epochs):
  for epoch in range(epochs):
    start = time.time()

    for image_batch in dataset:
      train_step(image_batch)

    # Produce images for the GIF as you go
    display.clear_output(wait=True)
    generate_and_save_images(generator,
                             epoch + 1,
                             seed)

    # Save the model every 2000 epochs
    if (epoch + 1) % 2000 == 0:
      checkpoint.save(file_prefix = checkpoint_prefix)

    print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))

  # Generate after the final epoch
  display.clear_output(wait=True)
  generate_and_save_images(generator,
                           epochs,
                           seed)

# %% [markdown]
# ## Generate and save images

# %%
def generate_and_save_images(model, epoch, test_input):
  # Notice `training` is set to False.
  # This is so all layers run in inference mode (batchnorm).
  predictions = model(test_input, training=False)

  fig = plt.figure(figsize=(3, 3))

  for i in range(predictions.shape[0]):
      plt.subplot(3, 3, i+1)
      plt.imshow(predictions[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
      plt.axis('off')

  plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
  plt.show()

# %% [markdown]
# # <u>Restore checkpoint </u>

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %% [markdown]
# ### Manual load generator and discriminator models

# %%
# Not needed if checkpoint is restored
command = input("Load generator and discriminator models: " + "\033[1m"  "y/n ?" "\033[0m" + " ")

if command.lower() == "y":
    generator = keras.models.load_model(r'C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Saved Models\ArchiGAN_Generator.h5')
    discriminator = keras.models.load_model(r'C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Saved Models\ArchiGAN_Discriminator.h5')
    print("\n\033[1m" + "Successful: generator and discriminator models are loaded." + "\033[0m")
elif command.lower() == "n":
    print("\n\033[1m" + "Unsuccessful: generator and discriminator models are not loaded." + "\033[0m")
else:
    print("\n\033[1m" + "Invalid input" + "\033[0m")
# Out:
# Load generator and discriminator models: y/n ? n
# Unsuccessful: generator and discriminator models are not loaded.

# %% [markdown]
# ### Manual save models

# %%
answer = input("Save generator and discriminator models: " + "\033[1m"  "y/n ?" "\033[0m" + " ")

if answer.lower() == "y":
    generator.save(r'C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Saved Models\ArchiGAN_Generator.h5')
    discriminator.save(r'C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Saved Models\ArchiGAN_Discriminator.h5')
    print("\n\033[1m" + "Successful: generator and discriminator models are saved." + "\033[0m")
elif answer.lower() == "n":
    print("\n\033[1m" + "Unsuccessful: generator and discriminator models are not saved." + "\033[0m")
else:
    print("\n\033[1m" + "Invalid input" + "\033[0m")
# Out:
# Save generator and discriminator models: y/n ? y
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
# Successful: generator and discriminator models are saved.

# %%
train(train_dataset, 200)

# %%
plt.imshow(generator(np.random.rand(1,100)).numpy().reshape(500,500),cmap="gray")

# %%
# Generating and saving plan pngs

def generate_plans():

    plt.imshow(generator(np.random.rand(1,100)).numpy().reshape(500,500),cmap="gray")

    if not os.listdir(r"C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans"):
        print('Folder is empty. Creating 1st plan:')
        plt.axis('off')
        plt.savefig(r'C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\Generated Plan 1.png',
                    dpi=300,
                    facecolor='w',
                    edgecolor='w',
                    orientation='portrait',
                    format=None,
                    transparent=False,
                    bbox_inches='tight',
                    pad_inches=0,
                    metadata=None)

    else:
        # Getting latest file
        directory = r"C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\*.png"
        file_list = glob.glob(directory)
        last_file = max(file_list, key=os.path.getctime)
        plan_name = os.path.basename(os.path.normpath(last_file))

        # Removing the file extension
        raw_name = plan_name.split(".")
        base_filename = raw_name[0]

        # Subsequent filename
        string = base_filename
        numbers = []
        for figure in string.split():
            if figure.isdigit():
                numbers.append(int(figure))

        output = ""
        for integer in numbers:
            output += str(integer)

        new_number = int(output) + 1
        subsequent_filename = "Generated Plan " + str(new_number) + ".png"
        subsequent_directory = r"C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans" + "\\" + subsequent_filename
        print(subsequent_directory)
        plt.axis('off')
        plt.savefig(subsequent_directory,
                    dpi=300,
                    facecolor='w',
                    edgecolor='w',
                    orientation='portrait',
                    format=None,
                    transparent=False,
                    bbox_inches='tight',
                    pad_inches=0,
                    metadata=None)

# %%
# Generate and Save Plans

number_of_generated_plans = 10
x = 0
while x < number_of_generated_plans:
    generate_plans()
    x += 1

print("Done")
# Out:
# C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\Generated Plan 51.png
# C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\Generated Plan 52.png
# C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\Generated Plan 53.png
# C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\Generated Plan 54.png
# C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\Generated Plan 55.png
# C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\Generated Plan 56.png
# C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\Generated Plan 57.png
# C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\Generated Plan 58.png
# C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\Generated Plan 59.png
# C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\Generated Plans\Generated Plan 60.png
# Done

# %% [markdown]
# ## Create GIF

# %%
def display_image(epoch_no):
  return PIL.Image.open('image_at_epoch_{:04d}.png'.format(epoch_no))

# %%
display_image(2000)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=288x288 at 0x20E1E732160>

# %%
anim_file = '23.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('image*.png')
  filenames = sorted(filenames)
  for filename in filenames:
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)

# %% [markdown]
# ## Save Checkpoint

# %%
checkpoint.save(file_prefix = checkpoint_prefix)

list_of_files = glob.glob(r"C:\Users\johnd\Desktop\GANs\Plan Generation 500 x 500\training_checkpoints\*.data-00000-of-00001")
latest_file = max(list_of_files, key=os.path.getctime)
# File name
file_name = os.path.basename(os.path.normpath(latest_file))
print("\n" + "Checkpoint file saved: " + "\033[1m" + file_name + "\033[0m")
# File size
size_bytes = os.path.getsize(latest_file)
# Converting bytes to megabytes (MB)
size_megabytes = round((int(size_bytes)/(1/9.537e-7)), 4)
print("\033[1m" + str(size_megabytes) + " MB" + "\033[0m")
# Out:
# Checkpoint file saved: ckpt-48.data-00000-of-00001
# 414.1888 MB
